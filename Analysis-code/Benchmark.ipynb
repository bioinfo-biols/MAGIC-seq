# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os
import re
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.sans-serif'] = 'Arial'
def plot_black(ax):
    plt.tick_params(colors='black')
    ax.spines['left'].set_color('black')
    ax.spines['right'].set_color('black')
    ax.spines['bottom'].set_color('black')
    ax.spines['top'].set_color('black')
    ax.xaxis.label.set_color('black')
    ax.yaxis.label.set_color('black')

# %% [markdown]
# # Benchmark-Sensitivity

# %%
df_stat = pd.read_csv('../file/source_data/Figure1d_2e_2f.csv',index_col=0)
df_stat
# Out:
#             UMI_median  Gene_median  UMI_mean  Gene_mean  raw_reads sample_id
# sample
# ZZJ_Reg1_1      3872.0       2341.0    3749.0     2218.0       10.0  ZZJ_Reg1  \
# ZZJ_Reg1_2      6655.0       3380.0    6430.0     3182.0       20.0  ZZJ_Reg1
# ZZJ_Reg1_3      8655.0       3983.0    8367.0     3745.0       30.0  ZZJ_Reg1
# ZZJ_Reg1_4     10146.0       4389.0    9787.0     4116.0       40.0  ZZJ_Reg1
# ZZJ_Reg1_5     11368.0       4697.0   10966.0     4402.0       50.0  ZZJ_Reg1
# ...                ...          ...       ...        ...        ...       ...
# MOB-15-1_2      5112.0       2568.0    5046.0     2485.0       20.0  MOB-15-1
# MOB-15-1_3      6247.0       2931.0    6156.0     2830.0       30.0  MOB-15-1
# MOB-15-1_4      7075.0       3192.0    6990.0     3070.0       40.0  MOB-15-1
# MOB-15-1_5      7760.0       3387.0    7665.0     3252.0       50.0  MOB-15-1
# MOB-15-1_6      8359.0       3551.0    8240.0     3400.0       60.0  MOB-15-1
#
# ...

# %%
o=['ZZJ_Reg1','ZZJ_Reg2','ZZJ_Reg3','sample1-1','S6_new',
   'WT1','WT2',
   'E10_0725e10cl','E10_10t',
   'BRAIN-50-1','MOB-50-1','MOB-15-1','HM-15-1']
p=['#ef3b2c','#ef3b2c','#ef3b2c','#cb181d','#fb6a4a','#2171b5','#2171b5',
                    '#dd3497','#f768a1','#41ab5d','#238b45','#74c476','#a1d99b']
import numpy as np
import pandas as pd
import seaborn as sns
plt.figure(figsize=(5,5))
sns.set(style="ticks", font_scale=1.3)
ax=sns.lineplot(data=df_stat, 
            markers=True,
             #dashes=False,
             style='methods',
             x='raw_reads',
             hue='sample_id',
             hue_order=o,
             palette=p,
             y='Gene_median',
             linewidth=1.8)
plt.title("Median nGene per spot",color='black')
plt.xlabel('Raw read counts per spot(k)',color='black')
plt.ylabel('nGene per spot',color='black')
plt.legend(loc=[1.1,0],labelcolor ='black')
plot_black(ax)

plt.show()

# %%
o=['ZZJ_Reg1','ZZJ_Reg2','ZZJ_Reg3','S6_new',
   'WT1','WT2',
   'E10_0725e10cl','E10_10t',
   'BRAIN-50-1','HM-15-1']
p=['#ef3b2c','#ef3b2c','#ef3b2c','#fb6a4a','#2171b5','#2171b5',
                    '#dd3497','#f768a1','#41ab5d','#a1d99b']
import numpy as np
import pandas as pd
import seaborn as sns
plt.figure(figsize=(5,5))
sns.set(style="ticks", font_scale=1.3)
ax=sns.lineplot(data=df_stat[df_stat['tissue']!='MOB'], 
            markers=True,
             #dashes=False,
             style='methods',
             x='raw_reads',
             hue='sample_id',
             hue_order=o,
             palette=p,
             y='Gene_median',
             linewidth=1.8)
plt.title("Median nGene per spot",color='black')
plt.xlabel('Raw read counts per spot(k)',color='black')
plt.ylabel('nGene per spot',color='black')
plt.legend(loc=[1.1,0],labelcolor ='black')
plt.ylim(0,6500)
plot_black(ax)

plt.show()

# %%
o=['sample1-1','MOB-50-1','MOB-15-1']
p=['#cb181d','#238b45','#74c476']
import numpy as np
import pandas as pd
import seaborn as sns
plt.figure(figsize=(5,5))
sns.set(style="ticks", font_scale=1.3)
ax=sns.lineplot(data=df_stat[df_stat['tissue']=='MOB'], 
            markers=True,
             #dashes=False,
             style='methods',
             x='raw_reads',
             hue='sample_id',
             hue_order=o,
             palette=p,
             y='Gene_median',
             linewidth=1.8)
plt.title("Median nGene per spot",color='black')
plt.xlabel('Raw read counts per spot(k)',color='black')
plt.ylabel('nGene per spot',color='black')
plt.legend(loc=[1.1,0],labelcolor ='black')
plot_black(ax)

plt.show()

# %%
o=['ZZJ_Reg1','ZZJ_Reg2','ZZJ_Reg3','sample1-1','S6_new',
   'WT1','WT2',
   'E10_0725e10cl','E10_10t',
   'BRAIN-50-1','MOB-50-1','MOB-15-1','HM-15-1']
p=['#ef3b2c','#ef3b2c','#ef3b2c','#cb181d','#fb6a4a','#2171b5','#2171b5',
                    '#dd3497','#f768a1','#41ab5d','#238b45','#74c476','#a1d99b']
import numpy as np
import pandas as pd
import seaborn as sns
plt.figure(figsize=(5,5))
sns.set(style="ticks", font_scale=1.3)
ax=sns.lineplot(data=df_stat, 
            markers=True,
             #dashes=False,
             style='methods',
             x='raw_reads',
             hue='sample_id',
             hue_order=o,
             palette=p,
             y='UMI_median',
             linewidth=1.8)
plt.title("Median nUMI per spot",color='black')
plt.xlabel('Raw read counts per spot(k)',color='black')
plt.ylabel('nUMI per sopt',color='black')
plt.legend(loc=[1.1,0],labelcolor ='black')
plt.ylim(0,33000)
plot_black(ax)

plt.show()

# %%
o=['ZZJ_Reg1','ZZJ_Reg2','ZZJ_Reg3','S6_new',
   'WT1','WT2',
   'E10_0725e10cl','E10_10t',
   'BRAIN-50-1','HM-15-1']
p=['#ef3b2c','#ef3b2c','#ef3b2c','#fb6a4a','#2171b5','#2171b5',
                    '#dd3497','#f768a1','#41ab5d','#a1d99b']
import numpy as np
import pandas as pd
import seaborn as sns
plt.figure(figsize=(5,5))
sns.set(style="ticks", font_scale=1.3)
ax=sns.lineplot(data=df_stat[df_stat['tissue']!='MOB'], 
            markers=True,
             #dashes=False,
             style='methods',
             x='raw_reads',
             hue='sample_id',
             hue_order=o,
             palette=p,
             y='UMI_median',
             linewidth=1.8)
plt.title("Median nUMI per spot",color='black')
plt.xlabel('Raw read counts per spot(k)',color='black')
plt.ylabel('nUMI per spot',color='black')
plt.legend(loc=[1.1,0],labelcolor ='black')
plt.ylim(0,19000)
plot_black(ax)

plt.show()

# %%
o=['sample1-1','MOB-50-1','MOB-15-1']
p=['#cb181d','#238b45','#74c476']
import numpy as np
import pandas as pd
import seaborn as sns
plt.figure(figsize=(5,5))
sns.set(style="ticks", font_scale=1.3)
ax=sns.lineplot(data=df_stat[df_stat['tissue']=='MOB'], 
            markers=True,
             #dashes=False,
             style='methods',
             x='raw_reads',
             hue='sample_id',
             hue_order=o,
             palette=p,
             y='UMI_median',
             linewidth=1.8)
plt.title("Median nUMI per spot",color='black')
plt.xlabel('Raw read counts per spot(k)',color='black')
plt.ylabel('nUMI per spot',color='black')
plt.legend(loc=[1.1,0],labelcolor ='black')
plt.ylim(0,33000)
plot_black(ax)

plt.show()

# %%
df_stat = pd.read_csv('../file/source_data/Figure1C_S2C_S2D.csv',index_col=0)
df_stat
# Out:
#          UMI  GENE            sample                  methods tissue
# 0       2058  1355  E10_0725e10cl-10     DBiT-seq\n(E10,50um)    E10
# 1      13834  5077  E10_0725e10cl-10     DBiT-seq\n(E10,50um)    E10
# 2      12421  4865  E10_0725e10cl-10     DBiT-seq\n(E10,50um)    E10
# 3       3175  1937  E10_0725e10cl-10     DBiT-seq\n(E10,50um)    E10
# 4       7937  3668  E10_0725e10cl-10     DBiT-seq\n(E10,50um)    E10
# ...      ...   ...               ...                      ...    ...
# 29896    562   407        MOB-15-1_6  Decoder-seq\n(MOB,15um)    MOB
# 29897    429   283        MOB-15-1_6  Decoder-seq\n(MOB,15um)    MOB
# 29898    310   202        MOB-15-1_6  Decoder-seq\n(MOB,15um)    MOB
# 29899    362   217        MOB-15-1_6  Decoder-seq\n(MOB,15um)    MOB
# 29900    303   190        MOB-15-1_6  Decoder-seq\n(MOB,15um)    MOB
#
# [29901 rows x 5 columns]

# %%
p_dict={'MAGIC-seq\n(Brain,50um)':'#cb181d',
   'Decoder-seq\n(Brain,50um)':'#238b45',
   '10x Visium\n(Brain,55um)':'#2171b5',
   'DBiT-seq\n(E10,50um)':'#dd3497',
   'MAGIC-seq\n(MOB,50um)':'#cb181d',
    'Decoder-seq\n(MOB,50um)':'#238b45',
 'MAGIC-seq\n(HIP,15um)':'#cb181d',
 'Decoder-seq\n(HIP,15um)':'#238b45',
 'Decoder-seq\n(MOB,15um)':'#238b45',
 'DBiT-seq\n(E10,10um)':'#c84993'}

o=['MAGIC-seq\n(Brain,50um)',
   '10x Visium\n(Brain,55um)',
   'Decoder-seq\n(Brain,50um)',
   'DBiT-seq\n(E10,50um)',
    'MAGIC-seq\n(MOB,50um)',
   'Decoder-seq\n(MOB,50um)',
   'Decoder-seq\n(MOB,15um)',
   'MAGIC-seq\n(HIP,15um)', 
   'Decoder-seq\n(HIP,15um)',
  'DBiT-seq\n(E10,10um)']

plt.figure(figsize=(8,4.5))
sns.set(style="ticks",font_scale=1.2)

ax=sns.violinplot(data=df_stat, 
               x='methods',
               y='GENE', 
               order=o,
               width=1.3, 
               palette=p_dict,
               linewidth=1)

plt.title("Gene counts per spot \n (100k/60k raw read count per 50um/15um spot)",color='black')
plt.ylabel('nGene per spot',color='black')
plt.xticks(rotation=45)
plot_black(ax)
ax.get_xticklabels()[0].set_color("red")  
ax.get_xticklabels()[4].set_color("red")  
ax.get_xticklabels()[7].set_color("red")  


plt.show()

# %%
p_dict={'MAGIC-seq\n(Brain,50um)':'#cb181d',
   'Decoder-seq\n(Brain,50um)':'#238b45',
   '10x Visium\n(Brain,55um)':'#2171b5',
   'DBiT-seq\n(E10,50um)':'#dd3497',
 'MAGIC-seq\n(HIP,15um)':'#cb181d',
 'Decoder-seq\n(HIP,15um)':'#238b45',
 'DBiT-seq\n(E10,10um)':'#c84993'}

o=['MAGIC-seq\n(Brain,50um)',
   '10x Visium\n(Brain,55um)',
   'Decoder-seq\n(Brain,50um)',
   'DBiT-seq\n(E10,50um)',
   'MAGIC-seq\n(HIP,15um)', 
   'Decoder-seq\n(HIP,15um)',
  'DBiT-seq\n(E10,10um)']

plt.figure(figsize=(8,4.5))
sns.set(style="ticks",font_scale=1.2)

ax=sns.violinplot(data=df_stat[df_stat['tissue']!='MOB'], 
               x='methods',
               y='GENE', 
               order=o,
               width=1.3, 
               palette=p_dict,
               linewidth=1)

plt.title("Gene counts per spot \n (100k/60k raw read count per 50um/15um spot)",color='black')
plt.ylabel('nGene per spot',color='black')
plt.xticks(rotation=30)
plot_black(ax)
ax.get_xticklabels()[0].set_color("red")  
ax.get_xticklabels()[4].set_color("red")  

plt.show()

# %%
p_dict={'MAGIC-seq\n(MOB,50um)':'#cb181d',
    'Decoder-seq\n(MOB,50um)':'#238b45',
 'Decoder-seq\n(MOB,15um)':'#238b45'}

o=['MAGIC-seq\n(MOB,50um)',
    'Decoder-seq\n(MOB,50um)',
 'Decoder-seq\n(MOB,15um)']

plt.figure(figsize=(4.5,4.5))
sns.set(style="ticks",font_scale=1.2)

ax=sns.violinplot(data=df_stat[df_stat['tissue']=='MOB'], 
               x='methods',
               y='GENE', 
               order=o,
               width=0.9, 
               palette=p_dict,
               linewidth=1)

plt.title("Gene counts per spot \n (100k/60k raw read count per 50um/15um spot)",color='black')
plt.ylabel('nGene per spot',color='black')
plt.xticks(rotation=30)
plot_black(ax)
ax.get_xticklabels()[0].set_color("red")  

plt.show()

# %%
p_dict={'MAGIC-seq\n(Brain,50um)':'#cb181d',
   'Decoder-seq\n(Brain,50um)':'#238b45',
   '10x Visium\n(Brain,55um)':'#2171b5',
   'DBiT-seq\n(E10,50um)':'#dd3497',
   'MAGIC-seq\n(MOB,50um)':'#cb181d',
    'Decoder-seq\n(MOB,50um)':'#238b45',
 'MAGIC-seq\n(HIP,15um)':'#cb181d',
 'Decoder-seq\n(HIP,15um)':'#238b45',
 'Decoder-seq\n(MOB,15um)':'#238b45',
 'DBiT-seq\n(E10,10um)':'#c84993'}

o=['MAGIC-seq\n(Brain,50um)',
   '10x Visium\n(Brain,55um)',
   'Decoder-seq\n(Brain,50um)',
   'DBiT-seq\n(E10,50um)',
    'MAGIC-seq\n(MOB,50um)',
   'Decoder-seq\n(MOB,50um)',
   'Decoder-seq\n(MOB,15um)',
   'MAGIC-seq\n(HIP,15um)', 
   'Decoder-seq\n(HIP,15um)',
  'DBiT-seq\n(E10,10um)']

plt.figure(figsize=(8,4.5))
sns.set(style="ticks",font_scale=1.2)

ax=sns.violinplot(data=df_stat, 
               x='methods',
               y='UMI', 
               order=o,
               width=1.3, 
               palette=p_dict,
               linewidth=1)

plt.title("UMI counts per spot \n (100k/60k raw read count per 50um/15um spot)",color='black')
plt.ylabel('nUMI per spot',color='black')
plt.xticks(rotation=45)
plot_black(ax)
ax.get_xticklabels()[0].set_color("red")  
ax.get_xticklabels()[4].set_color("red")  
ax.get_xticklabels()[7].set_color("red")  

plt.show()

# %%
p_dict={'MAGIC-seq\n(Brain,50um)':'#cb181d',
   'Decoder-seq\n(Brain,50um)':'#238b45',
   '10x Visium\n(Brain,55um)':'#2171b5',
   'DBiT-seq\n(E10,50um)':'#dd3497',
 'MAGIC-seq\n(HIP,15um)':'#cb181d',
 'Decoder-seq\n(HIP,15um)':'#238b45',
 'DBiT-seq\n(E10,10um)':'#c84993'}

o=['MAGIC-seq\n(Brain,50um)',
   '10x Visium\n(Brain,55um)',
   'Decoder-seq\n(Brain,50um)',
   'DBiT-seq\n(E10,50um)',
   'MAGIC-seq\n(HIP,15um)', 
   'Decoder-seq\n(HIP,15um)',
  'DBiT-seq\n(E10,10um)']

plt.figure(figsize=(8,4.5))
sns.set(style="ticks",font_scale=1.2)

ax=sns.violinplot(data=df_stat[df_stat['tissue']!='MOB'], 
               x='methods',
               y='UMI', 
               order=o,
               width=1.3, 
               palette=p_dict,
               linewidth=1)

plt.title("UMI counts per spot \n (100k/60k raw read count per 50um/15um spot)",color='black')
plt.ylabel('nUMI per spot',color='black')
plt.xticks(rotation=30)
plot_black(ax)
ax.get_xticklabels()[0].set_color("red")  
ax.get_xticklabels()[4].set_color("red")  

plt.show()

# %%
p_dict={'MAGIC-seq\n(MOB,50um)':'#cb181d',
    'Decoder-seq\n(MOB,50um)':'#238b45',
 'Decoder-seq\n(MOB,15um)':'#238b45'}

o=['MAGIC-seq\n(MOB,50um)',
    'Decoder-seq\n(MOB,50um)',
 'Decoder-seq\n(MOB,15um)']

plt.figure(figsize=(4.5,4.5))
sns.set(style="ticks",font_scale=1.2)

ax=sns.violinplot(data=df_stat[df_stat['tissue']=='MOB'], 
               x='methods',
               y='UMI', 
               order=o,
               width=0.9, 
               palette=p_dict,
               linewidth=1)

plt.title("UMI counts per spot \n (100k/60k raw read count per 50um/15um spot)",color='black')
plt.ylabel('nUMI per spot',color='black')
plt.xticks(rotation=30)
plot_black(ax)
ax.get_xticklabels()[0].set_color("red")  

plt.show()

# %% [markdown]
# # Benchmark-barcoding efficacy

# %%
import math
barcode_num=[20,30,40,50,60,70,80,90,100]
barcode_num=[i for i in range(0,4900,50)]

barcode_num_10X=[i  for i in barcode_num]
barcode_num_dbit=[math.pow(i,2) for i in barcode_num]
barcode_num_Map=[math.pow((i-9),2)*9  for i in barcode_num]
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Data
df=pd.DataFrame({'barcode_num': barcode_num_10X, 'barcode_num_dbit': barcode_num_dbit, 'barcode_num_Map': barcode_num_Map})
 
plt.figure(figsize=(3,3))
# multiple line plots
plt.plot( barcode_num_10X, barcode_num_10X,  marker='',  markersize=2, color='#dd8452', linewidth=2,label="10X")

plt.plot( barcode_num_10X, barcode_num_dbit, marker='', color='#c44e52', linewidth=2,label="DBiT-seq \nDecoder-seq")

plt.plot( barcode_num_10X, barcode_num_Map,  marker='', color='#8172b3', linewidth=2,
         #linestyle='dashed',
         label="MAGIC-seq")

# show legend
plt.legend()

plt.xlabel('Number of barcode type', labelpad=5,color='black')
plt.ylabel('Number of spot', labelpad=5,color='black')
# show graph
plot_black(ax)
plt.show()

# %% [markdown]
# # Benchmark-area

# %%
df_area=pd.read_csv('../file/source_data/Methods-areas.csv')
df_area
# Out:
#              Methods  area(mm2)    spot  barcode
# 0    MAGIC-seq(15um)         42   44100      158
# 1    MAGIC-seq(20um)        346  202500      318
# 2    MAGIC-seq(50um)        467   44100      158
# 3   10x Visium(55um)         42    4992     4992
# 4     DBiT-seq(50um)         25    2500      100
# 5     DBiT-seq(10um)          1    2500      100
# 6  Decoder-seq(15um)          9   10000      200
# 7  Decoder-seq(25um)         25   10000      200
# 8  Decoder-seq(50um)         25    2500      100

# %%
p=['#cb181d','#ef3b2c','#fb6a4a','#2171b5','#dd3497','#f768a1',
                    '#238b45','#41ab5d','#74c476']

p=['#cb181d','#ef3b2c','#fb6a4a','#adadad','#adadad','#adadad',
                    '#adadad','#adadad','#adadad']

a=['MAGIC-seq(50um)',
  'MAGIC-seq(20um)',
   'MAGIC-seq(15um)',
  '10x Visium(55um)',
   'DBiT-seq(50um)',
   'DBiT-seq(10um)',
   'Decoder-seq(50um)',
   'Decoder-seq(25um)',
   'Decoder-seq(15um)']
c_dict=dict(zip(a,p))

a=['MAGIC-seq(50um)',
   '10x Visium(55um)',
      'DBiT-seq(50um)',
   'Decoder-seq(50um)',
     'MAGIC-seq(20um)',
      'Decoder-seq(25um)',
   'MAGIC-seq(15um)',
    'Decoder-seq(15um)',
   'DBiT-seq(10um)'
]

# %%
from pandas.api.types import CategoricalDtype
CategoricalDtype(a,ordered=True)
df_area['Methods'] = df_area['Methods'].astype(CategoricalDtype(a,ordered=True))
df_area.sort_values('Methods',inplace=True)

# %%
#df_area['area(mm2)'] = np.log(df_area['area(mm2)'])

# %%
from pandas.api.types import CategoricalDtype
CategoricalDtype(a,ordered=True)
df_area['Methods'] = df_area['Methods'].astype(CategoricalDtype(a[::-1],ordered=True))
df_area.sort_values('Methods',inplace=True)

# 创建两个绘图坐标轴；调整两个轴之间的距离，即轴断点距离
fig, (ax1) = plt.subplots(1, 1, sharey='all',figsize=(5, 5))
fig.subplots_adjust(wspace=0.05)

#ax1.set_yticks(a)

ax1.barh(y=df_area['Methods'],width=df_area['area(mm2)'],
         height=0.8,
         color=[c_dict[i] for i in a][::-1],
         edgecolor='none')


ax1.set_xlim(0, 520)  # outliers only
ax1.spines['top'].set_visible(False)##关闭子图1中顶部脊
ax1.spines['right'].set_visible(False)##关闭子图1中顶部脊


# 隐藏y轴刻度
ax2.tick_params(axis='y',length=0)  # 隐藏y轴刻度
# ax2.xaxis.tick_bottom()

ax1.set_ylabel('Methods', labelpad=5,color='black')

plot_black(ax1)
plt.savefig('D:/Task/Project/MAGIC_seq/Figure/Figure1/Fig1-area2.pdf', dpi = 300, transparent=True, format = 'pdf', bbox_inches='tight')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %%
p=['#cb181d','#ef3b2c','#fb6a4a','#2171b5','#dd3497','#f768a1',
                    '#238b45','#41ab5d','#74c476']
a=['MAGIC-seq(50um)',
  'MAGIC-seq(20um)',
   'MAGIC-seq(15um)',
  '10x Visium(55um)',
   'DBiT-seq(50um)',
   'DBiT-seq(10um)',
   'Decoder-seq(50um)',
   'Decoder-seq(25um)',
   'Decoder-seq(15um)']
c_dict=dict(zip(a,p))

a=['MAGIC-seq(50um)',
   '10x Visium(55um)',
      'DBiT-seq(50um)',
   'Decoder-seq(50um)',
     'MAGIC-seq(20um)',
      'Decoder-seq(25um)',
   'MAGIC-seq(15um)',
    'Decoder-seq(15um)',
   'DBiT-seq(10um)'
]

from pandas.api.types import CategoricalDtype
CategoricalDtype(a,ordered=True)
df_area['Methods'] = df_area['Methods'].astype(CategoricalDtype(a[::-1],ordered=True))
df_area.sort_values('Methods',inplace=True)

# 创建两个绘图坐标轴；调整两个轴之间的距离，即轴断点距离
fig, (ax1) = plt.subplots(1, 1, sharey='all',figsize=(5, 5))
fig.subplots_adjust(wspace=0.05)

#ax1.set_yticks(a)

ax1.barh(y=df_area['Methods'],width=df_area['area(mm2)'],
         height=0.8,
         color=[c_dict[i] for i in a][::-1],
         edgecolor='none')

ax1.set_xlim(0, 520)  # outliers only
ax1.spines['top'].set_visible(False)##关闭子图1中顶部脊
ax1.spines['right'].set_visible(False)##关闭子图1中顶部脊


# 隐藏y轴刻度
ax2.tick_params(axis='y',length=0)  # 隐藏y轴刻度
# ax2.xaxis.tick_bottom()

ax1.set_ylabel('Methods', labelpad=5,color='black')

plot_black(ax1)
plt.savefig('D:/Task/Project/MAGIC_seq/Figure/Figure1/Fig1-area1.pdf', dpi = 300, transparent=True, format = 'pdf', bbox_inches='tight')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# # Benchmark-cost

# %%
c = ['#adadad','#adadad','#adadad','#adadad','#adadad','#c1272d']

# libraries
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# 创建两个绘图坐标轴；调整两个轴之间的距离，即轴断点距离
sns.set(style="ticks", font_scale=1.3)
fig, (ax1) = plt.subplots(1, 1, figsize=(6.2, 2.5))
fig.subplots_adjust(wspace=0.05)

cost = [35*49, 1250, 280.9, 102.8,  0.5*49, 0.11*49]
bars = [ 'Stereo-seq','10x Visium','DBiT', 'xDBiT', 'Decoder-seq','MAGIC-seq']
x_pos = np.arange(len(bars))
#ax1.bar(bars, list(np.log(np.array(cost)+1)),color=c,edgecolor='none')
ax1.bar(bars, list(np.sqrt(np.array(cost)+1)),color=c,edgecolor='none')
#ax1.bar(bars, cost,color=c,edgecolor='none')
#ax1.bar(bars, cost,color=['#f7931e','#2171b5','#dd3497','#f01463','#39b54a','#cb181d'])
#ax1.set_ylim(34,2400)

ax1.spines['right'].set_visible(False)#关闭子图2中底部脊
ax1.spines['top'].set_visible(False)##关闭子图1中顶部脊

plt.xticks(rotation=45)
ax1.set_ylabel('Cost($)', labelpad=5,color='black')
plot_black(ax1)
plt.savefig('D:/Task/Project/MAGIC_seq/Figure/Figure1/Fig1-cost1.pdf', dpi = 300, transparent=True, format = 'pdf', bbox_inches='tight')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %%
# libraries
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# 创建两个绘图坐标轴；调整两个轴之间的距离，即轴断点距离
sns.set(style="ticks", font_scale=1.3)
fig, (ax1) = plt.subplots(1, 1, figsize=(6.2, 2.5))
fig.subplots_adjust(wspace=0.05)

cost = [35, 1250/(6.5*6.5),11.2, 7.1, 0.5,0.11]
bars = [ 'Stereo-seq','10x Visium','DBiT', 'xDBiT', 'Decoder-seq','MAGIC-seq']
x_pos = np.arange(len(bars))
#ax1.bar(bars, list(np.log(np.array(cost)+1)),color=c,edgecolor='none')
ax1.bar(bars, list(np.sqrt(np.array(cost))),color=c,edgecolor='none')
#ax1.bar(bars, cost,color=c,edgecolor='none')
#ax1.bar(bars, cost,color=['#f7931e','#2171b5','#dd3497','#f01463','#39b54a','#cb181d'])
#ax1.set_ylim(34,2400)

ax1.spines['right'].set_visible(False)#关闭子图2中底部脊
ax1.spines['top'].set_visible(False)##关闭子图1中顶部脊

plt.xticks(rotation=45)
ax1.set_ylabel('Cost($)', labelpad=5,color='black')
plot_black(ax1)
plt.savefig('D:/Task/Project/MAGIC_seq/Figure/Figure1/Fig1-cost2.pdf', dpi = 300, transparent=True, format = 'pdf', bbox_inches='tight')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %%
# libraries
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# 创建两个绘图坐标轴；调整两个轴之间的距离，即轴断点距离
sns.set(style="ticks", font_scale=1.3)
fig, (ax1) = plt.subplots(1, 1, figsize=(6.2, 2.5))
fig.subplots_adjust(wspace=0.05)

cost = [35*49/(70*70),1250/5000, 0.112, 0.071, 0.5*49/4900, 0.11*49/4900]
bars = [ 'Stereo-seq','10x Visium','DBiT', 'xDBiT', 'Decoder-seq','MAGIC-seq']
x_pos = np.arange(len(bars))
#ax1.bar(bars, list(np.log(np.array(cost)+1)),color=c,edgecolor='none')
ax1.bar(bars, list(np.sqrt(np.array(cost))),color=c,edgecolor='none')
#ax1.bar(bars, cost,color=c,edgecolor='none')
#ax1.bar(bars, cost,color=['#f7931e','#2171b5','#dd3497','#f01463','#39b54a','#cb181d'])
#ax1.set_ylim(34,2400)

ax1.spines['right'].set_visible(False)#关闭子图2中底部脊
ax1.spines['top'].set_visible(False)##关闭子图1中顶部脊
plt.xticks(rotation=45)
ax1.set_ylabel('Cost($)', labelpad=5,color='black')
plot_black(ax1)
plt.savefig('D:/Task/Project/MAGIC_seq/Figure/Figure1/Fig1-cost3.pdf', dpi = 300, transparent=True, format = 'pdf', bbox_inches='tight')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
plt.figure(figsize=(5,5))
sns.set(style="ticks", font_scale=1.3)
# Set data
df = pd.DataFrame({
'group': ['MAGIC-seq','Stereo-seq','10x visum','Slide-seqv2','DBiT-seq','Decoder-seq'],
'Area': [4,4, 3, 2 , 3 , 3 ],
'Resolution': [3,4, 2, 3, 3, 3],
'Cost': [4,1, 2, 1, 3, 3.5],
'Throughput': [4,2, 3, 2, 2,2],
'Sensitivity': [3,3, 3, 2,3,3]
})
# ------- PART 1: Create background
# number of variable
categories=list(df)[1:]
N = len(categories)
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories)
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([1,2,3], ["1","2","3"], color="grey", size=7)
plt.ylim(0,4)
# ------- PART 2: Add plots
# Plot each individual = each line of the data
# I don't make a loop, because plotting more than 3 groups makes the chart unreadable
# Ind1

# Ind3

values=df.loc[1].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid',color='#f7931e', label="Stereo-seq")
ax.fill(angles, values, '#f7931e', alpha=0.1)
# Ind2
values=df.loc[2].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid',color='#2171b5' ,label="10x Visium")
ax.fill(angles, values, '#e49c75', alpha=0.0)

# Ind3
values=df.loc[3].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', color='#ffeda0',label="Slide-seqv2")
ax.fill(angles, values, '#ffeda0', alpha=0.0)

# Ind3
values=df.loc[4].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', color='#dd3497', label="DBiT-seq")
ax.fill(angles, values, '#dd3497', alpha=0.0)
  
# Ind3
values=df.loc[5].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid',color= '#39b54a',label="Decoder-seq")
ax.fill(angles, values, '#39b54a', alpha=0.0)
      
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=2, linestyle='solid',color= '#cb181d',label="MAGIC-seq")
ax.fill(angles, values, '#cb181d', alpha=0.1)

# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(1.6, 0.5))
plt.tick_params(colors='black')

plt.show()

# %% [markdown]
# # Fig1 I

# %%
df_plot = pd.read_csv('../file/source_data/Figure1I.csv')

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
plt.figure(figsize=(4,6))
sns.set(style="ticks",font_scale=1.2)
# Grouped violinplot
ax=sns.boxplot(x="type", y="CV",
            dodge=False,palette=['#abc9ea','#efb792','#98daa7','#f2aaa7'],
            fliersize=0,
            data=df_plot)
ax.spines['right'].set_visible(False)#关闭子图2中底部脊
ax.spines['top'].set_visible(False)##关闭子图1中顶部脊
#plt.hlines(25,colors='#e09266',linestyles='dashed')
plt.ylim(-1,23)
#plt.hlines(25,xmin=0,xmax=2,colors='red',linestyles='dashed')
#sns.despine(offset=10, trim=True)
plt.xticks(rotation = 40)
plot_black(ax)

plt.show()
